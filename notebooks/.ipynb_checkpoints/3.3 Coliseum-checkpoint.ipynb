# %% [markdown]
# # The Coliseum class
#
# The Coliseum Class contains all the Entry and Exit strategies and provides an interface to interact with all of them in order to:
# - Compute the EntryRequest and ExitRequests.
# - Plot the strategies.
#
# The things it does not do are:
# - It does not create the exit strategies when an entry trade is created.
#
# In order to work with the *Coliseum* objects, we need to first create a *Portfolio* object and one or more *Strategy* objects. The following code will take care of that.

# %% [markdown]
# ### Import libraries

# %%
import datetime as dt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
from IPython.display import Image
# %matplotlib qt

import sys
sys.path.insert(0, "..")  # Adds higher directory to python modules path.

from traphing.data_classes import Velas, Portfolio

from traphing.strategies import Trade, Coliseum
from traphing.strategies.entry import EntryStrategy, CrossingMovingAverages
from traphing.strategies.exit import ExitStrategy, StopLoss

from traphing.utils import Timeframes, unwrap
import traphing.utils  as ul

from traphing.graph.Gl import gl

folder_images = "./images/python_generated/strategies/"

# %% [markdown]
# ### Set up a portfolio

# %%
symbol_names = ["AUDCHF"]
timeframes = [Timeframes.M15]
portfolio_name = "my_portfolio"

storage_folder = "../tests/data/storage/"

portfolio = Portfolio(portfolio_name, symbol_names, timeframes)
portfolio.load_data_from_csv(storage_folder)

start_time = dt.datetime(2019,7,20); end_time = dt.datetime(2019,7,25)
portfolio.set_time_interval(start_time,end_time)
# Out:
# Size ../tests/data/storage/M15/AUDCHF_M15.csv:  100400  rows

# %% [markdown]
# ### Create one or more entry trading strategies

# %%
timeframe = timeframes[0]
symbol_name = symbol_names[0]
# First entry strategy
entry_strategy1 = CrossingMovingAverages("Crossing averages 1", portfolio)
symbol_name = symbol_names[0]
slow_MA_params = {"symbol_name":symbol_name,"timeframe": timeframe,"indicator_name":"SMA", "args": {"n":45}}
fast_MA_params = {"symbol_name":symbol_name,"timeframe": timeframe,"indicator_name":"SMA", "args":{"n":20}}
entry_strategy1.set_slow_MA(slow_MA_params)
entry_strategy1.set_fast_MA(fast_MA_params)

# Second entry strategy
entry_strategy2 = CrossingMovingAverages("Crossing averages 2", portfolio)
slow_MA_params = {"symbol_name":symbol_name,"timeframe": timeframe,"indicator_name":"SMA", "args": {"n":50}}
fast_MA_params = {"symbol_name":symbol_name,"timeframe": timeframe,"indicator_name":"SMA", "args":{"n":10}}
entry_strategy2.set_slow_MA(slow_MA_params)
entry_strategy2.set_fast_MA(fast_MA_params)

# %% [markdown]
# ## Coliseum instance
#
# There is no initialization parameters for the Coliseum class. When an instance is created, the internal data structures are initilized with no data.

# %%
coliseum = Coliseum()

# %% [markdown]
# ### Adding and deleting strategies
#
# Once the object is created, we add strategies by simply feeding the strategy objects.

# %%
coliseum.add_entry_strategy(entry_strategy1)
coliseum.add_entry_strategy(entry_strategy2)

# %%
coliseum.entry_strategies_ids_list
# Out:
# ['Crossing averages 1', 'Crossing averages 2']

# %%
coliseum.del_entry_strategy('Crossing averages 1')
coliseum.entry_strategies_ids_list
# Out:
# ['Crossing averages 2']

# %%
coliseum.add_entry_strategy(entry_strategy1)

# %%
coliseum.exit_strategies_ids_list
# Out:
# []

# %% [markdown]
# ## Handling the Priority Queue

# %%
queue = coliseum.compute_requests_queue()

# %%
unwrap(coliseum)
# Out:
# <Coliseum>	object has children:
#     <dict>	_entry_strategies_dict
#     <dict>	_exit_strategies_dict
#     <PriorityQueue>	queue
#
#   <PriorityQueue>	queue has children:
#       <int>	maxsize:	0
#       <list>	queue
#       <lock>	mutex
#       <Condition>	not_empty
#       <Condition>	not_full
#       <Condition>	all_tasks_done
#       <int>	unfinished_tasks:	12
#
#     <Condition>	all_tasks_done has children:
#         <lock>	_lock
#         <lock>	_lock
#         <lock>	_lock
#         <deque>	_waiters
#
#       <deque>	_waiters has children:
#
#       <lock>	_lock has children:
#
#       <lock>	_lock has children:
#
#       <lock>	_lock has children:
#
#     <Condition>	not_full has children:
#         <lock>	_lock
#         <lock>	_lock
#         <lock>	_lock
#         <deque>	_waiters
#
#       <deque>	_waiters has children:
#
#       <lock>	_lock has children:
#
#       <lock>	_lock has children:
#
#       <lock>	_lock has children:
#
#     <Condition>	not_empty has children:
#         <lock>	_lock
#         <lock>	_lock
#         <lock>	_lock
#         <deque>	_waiters
#
#       <deque>	_waiters has children:
#
#       <lock>	_lock has children:
#
#       <lock>	_lock has children:
#
#       <lock>	_lock has children:
#
#     <lock>	mutex has children:
#
#     <list>	queue has children:
#         <tuple>	queue[0]
#         <tuple>	queue[1]
#         <tuple>	queue[2]
#         <tuple>	queue[3]
#         <tuple>	queue[4]
#         <tuple>	queue[5]
#         <tuple>	queue[6]
#         <tuple>	queue[7]
#         <tuple>	queue[8]
#         <tuple>	queue[9]
#         <tuple>	queue[10]
#         <tuple>	queue[11]
#
#       <tuple>	queue[11] has children:
#           <Timestamp>	queue[11][0]:	2019-07-25 13:45:00
#           <EntryRequest>	queue[11][1]
#
#         <EntryRequest>	queue[11][1] has children:
#             <str>	strategy_id:	Crossing averages 1
#             <str>	entry_request_id:	4
#             <Timestamp>	candlestick_timestamp:	2019-07-25 13:45:00
#             <str>	symbol_name:	AUDCHF
#             <str>	BUYSELL:	BUY
#             <float>	price:	0.68683
#             <datetime>	signal_timestamp:	2019-10-20 22:12:50.375418
#             <int>	priority:	0
#             <int>	recommendedPosition:	1
#             <str>	tradingStyle:	dayTrading
#             <str>	comments:	Basic Crossing MA man !
#
#       <tuple>	queue[10] has children:
#           <Timestamp>	queue[10][0]:	2019-07-24 03:15:00
#           <EntryRequest>	queue[10][1]
#
#         <EntryRequest>	queue[10][1] has children:
#             <str>	strategy_id:	Crossing averages 1
#             <str>	entry_request_id:	3
#             <Timestamp>	candlestick_timestamp:	2019-07-24 03:15:00
#             <str>	symbol_name:	AUDCHF
#             <str>	BUYSELL:	SELL
#             <float>	price:	0.6887300000000001
#             <datetime>	signal_timestamp:	2019-10-20 22:12:50.374329
#             <int>	priority:	0
#             <int>	recommendedPosition:	1
#             <str>	tradingStyle:	dayTrading
#             <str>	comments:	Basic Crossing MA man !
#
#       <tuple>	queue[9] has children:
#           <Timestamp>	queue[9][0]:	2019-07-25 05:15:00
#           <EntryRequest>	queue[9][1]
#
#         <EntryRequest>	queue[9][1] has children:
#             <str>	strategy_id:	Crossing averages 2
#             <str>	entry_request_id:	4
#             <Timestamp>	candlestick_timestamp:	2019-07-25 05:15:00
#             <str>	symbol_name:	AUDCHF
#             <str>	BUYSELL:	BUY
#             <float>	price:	0.6876
#             <datetime>	signal_timestamp:	2019-10-20 22:12:50.364686
#             <int>	priority:	0
#             <int>	recommendedPosition:	1
#             <str>	tradingStyle:	dayTrading
#             <str>	comments:	Basic Crossing MA man !
#
#       <tuple>	queue[8] has children:
#           <Timestamp>	queue[8][0]:	2019-07-23 16:30:00
#           <EntryRequest>	queue[8][1]
#
#         <EntryRequest>	queue[8][1] has children:
#             <str>	strategy_id:	Crossing averages 1
#             <str>	entry_request_id:	1
#             <Timestamp>	candlestick_timestamp:	2019-07-23 16:30:00
#             <str>	symbol_name:	AUDCHF
#             <str>	BUYSELL:	SELL
#             <float>	price:	0.6894
#             <datetime>	signal_timestamp:	2019-10-20 22:12:50.372268
#             <int>	priority:	0
#             <int>	recommendedPosition:	1
#             <str>	tradingStyle:	dayTrading
#             <str>	comments:	Basic Crossing MA man !
#
#       <tuple>	queue[7] has children:
#           <Timestamp>	queue[7][0]:	2019-07-23 15:30:00
#           <EntryRequest>	queue[7][1]
#
#         <EntryRequest>	queue[7][1] has children:
#             <str>	strategy_id:	Crossing averages 2
#             <str>	entry_request_id:	3
#             <Timestamp>	candlestick_timestamp:	2019-07-23 15:30:00
#             <str>	symbol_name:	AUDCHF
#             <str>	BUYSELL:	SELL
#             <float>	price:	0.69084
#             <datetime>	signal_timestamp:	2019-10-20 22:12:50.363533
#             <int>	priority:	0
#             <int>	recommendedPosition:	1
#             <str>	tradingStyle:	dayTrading
#             <str>	comments:	Basic Crossing MA man !
#
#       <tuple>	queue[6] has children:
#           <Timestamp>	queue[6][0]:	2019-07-25 12:15:00
#           <EntryRequest>	queue[6][1]
#
#         <EntryRequest>	queue[6][1] has children:
#             <str>	strategy_id:	Crossing averages 2
#             <str>	entry_request_id:	6
#             <Timestamp>	candlestick_timestamp:	2019-07-25 12:15:00
#             <str>	symbol_name:	AUDCHF
#             <str>	BUYSELL:	BUY
#             <float>	price:	0.6874600000000001
#             <datetime>	signal_timestamp:	2019-10-20 22:12:50.366935
#             <int>	priority:	0
#             <int>	recommendedPosition:	1
#             <str>	tradingStyle:	dayTrading
#             <str>	comments:	Basic Crossing MA man !
#
#       <tuple>	queue[5] has children:
#           <Timestamp>	queue[5][0]:	2019-07-25 06:15:00
#           <EntryRequest>	queue[5][1]
#
#         <EntryRequest>	queue[5][1] has children:
#             <str>	strategy_id:	Crossing averages 2
#             <str>	entry_request_id:	5
#             <Timestamp>	candlestick_timestamp:	2019-07-25 06:15:00
#             <str>	symbol_name:	AUDCHF
#             <str>	BUYSELL:	SELL
#             <float>	price:	0.68661
#             <datetime>	signal_timestamp:	2019-10-20 22:12:50.365843
#             <int>	priority:	0
#             <int>	recommendedPosition:	1
#             <str>	tradingStyle:	dayTrading
#             <str>	comments:	Basic Crossing MA man !
#
#       <tuple>	queue[4] has children:
#           <Timestamp>	queue[4][0]:	2019-07-24 01:00:00
#           <EntryRequest>	queue[4][1]
#
#         <EntryRequest>	queue[4][1] has children:
#             <str>	strategy_id:	Crossing averages 1
#             <str>	entry_request_id:	2
#             <Timestamp>	candlestick_timestamp:	2019-07-24 01:00:00
#             <str>	symbol_name:	AUDCHF
#             <str>	BUYSELL:	BUY
#             <float>	price:	0.68971
#             <datetime>	signal_timestamp:	2019-10-20 22:12:50.373280
#             <int>	priority:	0
#             <int>	recommendedPosition:	1
#             <str>	tradingStyle:	dayTrading
#             <str>	comments:	Basic Crossing MA man !
#
#       <tuple>	queue[3] has children:
#           <Timestamp>	queue[3][0]:	2019-07-23 09:15:00
#           <EntryRequest>	queue[3][1]
#
#         <EntryRequest>	queue[3][1] has children:
#             <str>	strategy_id:	Crossing averages 2
#             <str>	entry_request_id:	1
#             <Timestamp>	candlestick_timestamp:	2019-07-23 09:15:00
#             <str>	symbol_name:	AUDCHF
#             <str>	BUYSELL:	SELL
#             <float>	price:	0.69083
#             <datetime>	signal_timestamp:	2019-10-20 22:12:50.361367
#             <int>	priority:	0
#             <int>	recommendedPosition:	1
#             <str>	tradingStyle:	dayTrading
#             <str>	comments:	Basic Crossing MA man !
#
#       <tuple>	queue[2] has children:
#           <Timestamp>	queue[2][0]:	2019-07-23 11:00:00
#           <EntryRequest>	queue[2][1]
#
#         <EntryRequest>	queue[2][1] has children:
#             <str>	strategy_id:	Crossing averages 2
#             <str>	entry_request_id:	2
#             <Timestamp>	candlestick_timestamp:	2019-07-23 11:00:00
#             <str>	symbol_name:	AUDCHF
#             <str>	BUYSELL:	BUY
#             <float>	price:	0.69133
#             <datetime>	signal_timestamp:	2019-10-20 22:12:50.362440
#             <int>	priority:	0
#             <int>	recommendedPosition:	1
#             <str>	tradingStyle:	dayTrading
#             <str>	comments:	Basic Crossing MA man !
#
#       <tuple>	queue[1] has children:
#           <Timestamp>	queue[1][0]:	2019-07-23 04:00:00
#           <EntryRequest>	queue[1][1]
#
#         <EntryRequest>	queue[1][1] has children:
#             <str>	strategy_id:	Crossing averages 2
#             <str>	entry_request_id:	0
#             <Timestamp>	candlestick_timestamp:	2019-07-23 04:00:00
#             <str>	symbol_name:	AUDCHF
#             <str>	BUYSELL:	BUY
#             <float>	price:	0.69098
#             <datetime>	signal_timestamp:	2019-10-20 22:12:50.360284
#             <int>	priority:	0
#             <int>	recommendedPosition:	1
#             <str>	tradingStyle:	dayTrading
#             <str>	comments:	Basic Crossing MA man !
#
#       <tuple>	queue[0] has children:
#           <Timestamp>	queue[0][0]:	2019-07-23 04:00:00
#           <EntryRequest>	queue[0][1]
#
#         <EntryRequest>	queue[0][1] has children:
#             <str>	strategy_id:	Crossing averages 1
#             <str>	entry_request_id:	0
#             <Timestamp>	candlestick_timestamp:	2019-07-23 04:00:00
#             <str>	symbol_name:	AUDCHF
#             <str>	BUYSELL:	BUY
#             <float>	price:	0.69098
#             <datetime>	signal_timestamp:	2019-10-20 22:12:50.371196
#             <int>	priority:	0
#             <int>	recommendedPosition:	1
#             <str>	tradingStyle:	dayTrading
#             <str>	comments:	Basic Crossing MA man !
#
#   <dict>	_exit_strategies_dict has children:
#
#   <dict>	_entry_strategies_dict has children:
#       <CrossingMovingAverages>	Crossing averages 2
#       <CrossingMovingAverages>	Crossing averages 1
#
#     <CrossingMovingAverages>	Crossing averages 1 has children:
#         <str>	strategy_id:	Crossing averages 1
#         <Portfolio>	portfolio
#         <NoneType>	signal_params_list:	None
#         <int>	entry_requests_counter:	5
#         <PriorityQueue>	queue
#         <list>	series_names
#         <dict>	slow_MA
#         <dict>	fast_MA
#
#       <dict>	fast_MA has children:
#           <str>	symbol_name:	AUDCHF
#           <Timeframes>	timeframe:	Timeframes.M15
#           <str>	indicator_name:	SMA
#           <dict>	args
#
#         <dict>	args has children:
#             <int>	n:	20
#
#       <dict>	slow_MA has children:
#           <str>	symbol_name:	AUDCHF
#           <Timeframes>	timeframe:	Timeframes.M15
#           <str>	indicator_name:	SMA
#           <dict>	args
#
#         <dict>	args has children:
#             <int>	n:	45
#
#       <list>	series_names has children:
#           <str>	series_names[0]:	slow_MA
#           <str>	series_names[1]:	fast_MA
#
#       <PriorityQueue>	queue has children:
#           <int>	maxsize:	0
#           <list>	queue
#           <lock>	mutex
#           <Condition>	not_empty
#           <Condition>	not_full
#           <Condition>	all_tasks_done
#           <int>	unfinished_tasks:	5
#
#         <Condition>	all_tasks_done has children:
#             <lock>	_lock
#             <lock>	_lock
#             <lock>	_lock
#             <deque>	_waiters
#
#           <deque>	_waiters has children:
#
#           <lock>	_lock has children:
#
#           <lock>	_lock has children:
#
#           <lock>	_lock has children:
#
#         <Condition>	not_full has children:
#             <lock>	_lock
#             <lock>	_lock
#             <lock>	_lock
#             <deque>	_waiters
#
#           <deque>	_waiters has children:
#
#           <lock>	_lock has children:
#
#           <lock>	_lock has children:
#
#           <lock>	_lock has children:
#
#         <Condition>	not_empty has children:
#             <lock>	_lock
#             <lock>	_lock
#             <lock>	_lock
#             <deque>	_waiters
#
#           <deque>	_waiters has children:
#
#           <lock>	_lock has children:
#
#           <lock>	_lock has children:
#
#           <lock>	_lock has children:
#
#         <lock>	mutex has children:
#
#         <list>	queue has children:
#
#       <Portfolio>	portfolio has children:
#           <dict>	_symbols_dict
#
#         <dict>	_symbols_dict has children:
#             <Symbol>	AUDCHF
#
#           <Symbol>	AUDCHF has children:
#               <str>	symbol_name:	AUDCHF
#               <dict>	_velas_dict
#               <SymbolProperties>	properties
#               <MarketHours>	market_hours
#
#             <MarketHours>	market_hours has children:
#                 <NoneType>	open_time:	None
#                 <NoneType>	close_time:	None
#                 <NoneType>	trading_days_list:	None
#                 <NoneType>	special_days_dict:	None
#
#             <SymbolProperties>	properties has children:
#                 <str>	symbol_name:	AUDCHF
#                 <NoneType>	type:	None
#                 <NoneType>	country:	None
#                 <NoneType>	currency:	None
#                 <NoneType>	sector:	None
#                 <NoneType>	contract_size:	None
#                 <NoneType>	point_size:	None
#                 <NoneType>	min_tick_value:	None
#
#             <dict>	_velas_dict has children:
#                 <Velas>	Timeframes.M15
#
#               <Velas>	Timeframes.M15 has children:
#                   <str>	symbol_name:	AUDCHF
#                   <Timeframes>	timeframe:	Timeframes.M15
#                   <Timestamp>	start_time:	2019-07-20 00:00:00
#                   <Timestamp>	end_time:	2019-07-25 00:00:00
#                   <ndarray>	_time_mask:	[97532 97533 97534 97535 97536 97537 975
#                   <DataFrame>	_df
#                   <bool>	_trimmed:	False
#
#                 <DataFrame>	_df has children:
#                     <str>	columns:	['Open', 'High', 'Low', 'Close', 'Volume
#                     <DatetimeIndex>	index:	DatetimeIndex(['2015-08-14 23:45:00', '2
#
#     <CrossingMovingAverages>	Crossing averages 2 has children:
#         <str>	strategy_id:	Crossing averages 2
#         <Portfolio>	portfolio
#         <NoneType>	signal_params_list:	None
#         <int>	entry_requests_counter:	7
#         <PriorityQueue>	queue
#         <list>	series_names
#         <dict>	slow_MA
#         <dict>	fast_MA
#
#       <dict>	fast_MA has children:
#           <str>	symbol_name:	AUDCHF
#           <Timeframes>	timeframe:	Timeframes.M15
#           <str>	indicator_name:	SMA
#           <dict>	args
#
#         <dict>	args has children:
#             <int>	n:	10
#
#       <dict>	slow_MA has children:
#           <str>	symbol_name:	AUDCHF
#           <Timeframes>	timeframe:	Timeframes.M15
#           <str>	indicator_name:	SMA
#           <dict>	args
#
#         <dict>	args has children:
#             <int>	n:	50
#
#       <list>	series_names has children:
#           <str>	series_names[0]:	slow_MA
#           <str>	series_names[1]:	fast_MA
#
#       <PriorityQueue>	queue has children:
#           <int>	maxsize:	0
#           <list>	queue
#           <lock>	mutex
#           <Condition>	not_empty
#           <Condition>	not_full
#           <Condition>	all_tasks_done
#           <int>	unfinished_tasks:	7
#
#         <Condition>	all_tasks_done has children:
#             <lock>	_lock
#             <lock>	_lock
#             <lock>	_lock
#             <deque>	_waiters
#
#           <deque>	_waiters has children:
#
#           <lock>	_lock has children:
#
#           <lock>	_lock has children:
#
#           <lock>	_lock has children:
#
#         <Condition>	not_full has children:
#             <lock>	_lock
#             <lock>	_lock
#             <lock>	_lock
#             <deque>	_waiters
#
#           <deque>	_waiters has children:
#
#           <lock>	_lock has children:
#
#           <lock>	_lock has children:
#
#           <lock>	_lock has children:
#
#         <Condition>	not_empty has children:
#             <lock>	_lock
#             <lock>	_lock
#             <lock>	_lock
#             <deque>	_waiters
#
#           <deque>	_waiters has children:
#
#           <lock>	_lock has children:
#
#           <lock>	_lock has children:
#
#           <lock>	_lock has children:
#
#         <lock>	mutex has children:
#
#         <list>	queue has children:
#
#       <Portfolio>	portfolio has children:
#           <dict>	_symbols_dict
#
#         <dict>	_symbols_dict has children:
#             <Symbol>	AUDCHF
#
#           <Symbol>	AUDCHF has children:
#               <str>	symbol_name:	AUDCHF
#               <dict>	_velas_dict
#               <SymbolProperties>	properties
#               <MarketHours>	market_hours
#
#             <MarketHours>	market_hours has children:
#                 <NoneType>	open_time:	None
#                 <NoneType>	close_time:	None
#                 <NoneType>	trading_days_list:	None
#                 <NoneType>	special_days_dict:	None
#
#             <SymbolProperties>	properties has children:
#                 <str>	symbol_name:	AUDCHF
#                 <NoneType>	type:	None
#                 <NoneType>	country:	None
#                 <NoneType>	currency:	None
#                 <NoneType>	sector:	None
#                 <NoneType>	contract_size:	None
#                 <NoneType>	point_size:	None
#                 <NoneType>	min_tick_value:	None
#
#             <dict>	_velas_dict has children:
#                 <Velas>	Timeframes.M15
#
#               <Velas>	Timeframes.M15 has children:
#                   <str>	symbol_name:	AUDCHF
#                   <Timeframes>	timeframe:	Timeframes.M15
#                   <Timestamp>	start_time:	2019-07-20 00:00:00
#                   <Timestamp>	end_time:	2019-07-25 00:00:00
#                   <ndarray>	_time_mask:	[97532 97533 97534 97535 97536 97537 975
#                   <DataFrame>	_df
#                   <bool>	_trimmed:	False
#
#                 <DataFrame>	_df has children:
#                     <str>	columns:	['Open', 'High', 'Low', 'Close', 'Volume
#                     <DatetimeIndex>	index:	DatetimeIndex(['2015-08-14 23:45:00', '2

# %% [markdown]
# ## We can then process the requests

# %%
while (coliseum.queue.empty() == False):
    print(coliseum.queue.get())
# Out:
# (Timestamp('2019-07-23 04:00:00'), <traphing.strategies.entry._EntryRequest.EntryRequest object at 0x7f3244edea10>)
# (Timestamp('2019-07-23 04:00:00'), <traphing.strategies.entry._EntryRequest.EntryRequest object at 0x7f31f9cb58d0>)
# (Timestamp('2019-07-23 09:15:00'), <traphing.strategies.entry._EntryRequest.EntryRequest object at 0x7f320cb9ac10>)
# (Timestamp('2019-07-23 11:00:00'), <traphing.strategies.entry._EntryRequest.EntryRequest object at 0x7f31f9ccd390>)
# (Timestamp('2019-07-23 15:30:00'), <traphing.strategies.entry._EntryRequest.EntryRequest object at 0x7f31f9ccd490>)
# (Timestamp('2019-07-23 16:30:00'), <traphing.strategies.entry._EntryRequest.EntryRequest object at 0x7f3244eded90>)
# (Timestamp('2019-07-24 01:00:00'), <traphing.strategies.entry._EntryRequest.EntryRequest object at 0x7f31f9ca7110>)
# (Timestamp('2019-07-24 03:15:00'), <traphing.strategies.entry._EntryRequest.EntryRequest object at 0x7f31f9ca7e50>)
# (Timestamp('2019-07-25 05:15:00'), <traphing.strategies.entry._EntryRequest.EntryRequest object at 0x7f31f9ca7ed0>)
# (Timestamp('2019-07-25 06:15:00'), <traphing.strategies.entry._EntryRequest.EntryRequest object at 0x7f31f9ca7c10>)
# (Timestamp('2019-07-25 12:15:00'), <traphing.strategies.entry._EntryRequest.EntryRequest object at 0x7f31f9d06390>)
# (Timestamp('2019-07-25 13:45:00'), <traphing.strategies.entry._EntryRequest.EntryRequest object at 0x7f31f9ca78d0>)

# %%
image_name = "entry_and_exit.png"; img_path = folder_images + image_name
gl.init_figure()

n_strategies = len(coliseum.entry_strategies_ids_list)

n_rows, n_cols = n_strategies*2,1; size_inches = [12, 8]
ax = None; axes_list = []
for i in range(n_strategies*2):
    ax = gl.subplot2grid((n_rows, n_cols),(i,0), sharex = ax)
    axes_list.append(ax)
    
i = 0
for strategy_id in coliseum.entry_strategies_ids_list:
    ax1 = axes_list[i*2]; ax2 = axes_list[i*2+1]
    entry_strategy = coliseum.get_entry_strategy(strategy_id)
    entry_strategy_series = entry_strategy.compute_strategy_series()
    entry_series = entry_strategy.compute_entry_series()

    portfolio[symbol_name][timeframe].plot_barchart(axes = ax1, labels = ["", "", strategy_id])
    gl.plot(entry_strategy_series.index, entry_strategy_series, legend = list(entry_strategy_series.columns), axes =ax1)

    gl.stem(entry_strategy_series.index,entry_series, axes = ax2, legend = "Trades")

    i = i+1
gl.subplots_adjust(left=.09, bottom=.10, right=.90, top=.95, wspace=.20, hspace=0, hide_xaxis = True)

gl.save_figure(img_path, dpi = 100, size_inches = size_inches, close = True)
Image(img_path)
